# %%
# -*- coding: utf-8 -*-

# %%
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount('/content/drive')


if __name__ =="__main__":
  if len(sys.argv)>1:
    image = cv2.imread('/content/drive/My Drive/107-2Multimedia/img003.jpg', cv2.IMREAD_GRAYSCALE)
  else:
    print("Usge:python imgToArray.py imageFile")
  plt.imshow(image,cmap='gray')
  plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image2 = cv2.imread('/content/drive/My Drive/107-2Multimedia/img003.jpg', cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
image3 = cv2.imread('/content/drive/My Drive/107-2Multimedia/img003.jpg',cv2.IMREAD_UNCHANGED)
plt.imshow(cv2.cvtColor(image3,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image4 = cv2.imread('/content/drive/My Drive/107-2Multimedia/img003.jpg',0)
plt.imshow(image4)
plt.title('invert')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image5 = cv2.imread('/content/drive/My Drive/107-2Multimedia/img003.jpg')
gray = cv2.cvtColor(image5,cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[ 15,  16,  18, ...,  35,  36,  36],
#        [ 15,  17,  18, ...,  35,  36,  36],
#        [ 16,  17,  18, ...,  35,  36,  36],
#        ...,
#        [233, 230, 229, ..., 173, 172, 170],
#        [231, 229, 228, ..., 173, 171, 169],
#        [234, 235, 237, ..., 171, 172, 172]], dtype=uint8)

# %%
plt.imshow(gray,cmap = 'gray')
plt.title('gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image6 = cv2.imread('/content/drive/My Drive/107-2Multimedia/img003.jpg')
b,g,r = cv2.split(image6)
img = cv2.merge((r,g,b))
plt.imshow(img)
plt.title('color')
plt.xticks([])
plt.yticks([])
plt.show()
